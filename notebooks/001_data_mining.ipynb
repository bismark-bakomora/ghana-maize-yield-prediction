# %%
pip install pandas openmeteo-requests requests-cache retry-requests geopy
# Out:
# Requirement already satisfied: pandas in c:\users\epadd\anaconda3\lib\site-packages (2.2.3)
# Collecting openmeteo-requests
#   Downloading openmeteo_requests-1.7.5-py3-none-any.whl.metadata (11 kB)
# Collecting requests-cache
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Collecting retry-requests
#   Downloading retry_requests-2.0.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: geopy in c:\users\epadd\anaconda3\lib\site-packages (2.4.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\epadd\anaconda3\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\epadd\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\epadd\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\epadd\anaconda3\lib\site-packages (from pandas) (2025.2)
# Collecting niquests>=3.15.2 (from openmeteo-requests)
#   Downloading niquests-3.17.0-py3-none-any.whl.metadata (17 kB)
# Collecting openmeteo-sdk>=1.22.0 (from openmeteo-requests)
#   Downloading openmeteo_sdk-1.25.0-py3-none-any.whl.metadata (935 bytes)
# Requirement already satisfied: attrs>=21.2 in c:\users\epadd\anaconda3\lib\site-packages (from requests-cache) (24.3.0)
# Collecting cattrs>=22.2 (from requests-cache)
#   Downloading cattrs-25.3.0-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\epadd\anaconda3\lib\site-packages (from requests-cache) (4.3.7)
# Requirement already satisfied: requests>=2.22 in c:\users\epadd\anaconda3\lib\site-packages (from requests-cache) (2.32.3)
# Collecting url-normalize>=1.4 (from requests-cache)
#   Downloading url_normalize-2.2.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: urllib3>=1.25.5 in c:\users\epadd\anaconda3\lib\site-packages (from requests-cache) (2.3.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\epadd\anaconda3\lib\site-packages (from geopy) (2.1)
# Collecting attrs>=21.2 (from requests-cache)
#   Using cached attrs-25.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting typing-extensions>=4.14.0 (from cattrs>=22.2->requests-cache)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\epadd\anaconda3\lib\site-packages (from niquests>=3.15.2->openmeteo-requests) (3.3.2)
# Collecting urllib3-future<3,>=2.13.903 (from niquests>=3.15.2->openmeteo-requests)
#   Downloading urllib3_future-2.15.901-py3-none-any.whl.metadata (16 kB)
# Collecting wassima<3,>=1.0.1 (from niquests>=3.15.2->openmeteo-requests)
#   Downloading wassima-2.0.4-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: h11<1.0.0,>=0.11.0 in c:\users\epadd\anaconda3\lib\site-packages (from urllib3-future<3,>=2.13.903->niquests>=3.15.2->openmeteo-requests) (0.16.0)
# Collecting jh2<6.0.0,>=5.0.3 (from urllib3-future<3,>=2.13.903->niquests>=3.15.2->openmeteo-requests)
#   Downloading jh2-5.0.10-cp37-abi3-win_amd64.whl.metadata (4.1 kB)
# Collecting qh3<2.0.0,>=1.5.4 (from urllib3-future<3,>=2.13.903->niquests>=3.15.2->openmeteo-requests)
#   Downloading qh3-1.5.6-cp37-abi3-win_amd64.whl.metadata (4.9 kB)
# Collecting flatbuffers==25.9.23 (from openmeteo-sdk>=1.22.0->openmeteo-requests)
#   Downloading flatbuffers-25.9.23-py2.py3-none-any.whl.metadata (875 bytes)
# Requirement already satisfied: six>=1.5 in c:\users\epadd\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\epadd\anaconda3\lib\site-packages (from requests>=2.22->requests-cache) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\epadd\anaconda3\lib\site-packages (from requests>=2.22->requests-cache) (2025.7.14)
# Downloading openmeteo_requests-1.7.5-py3-none-any.whl (7.1 kB)
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
# Downloading retry_requests-2.0.0-py3-none-any.whl (15 kB)
# Downloading cattrs-25.3.0-py3-none-any.whl (70 kB)
# Downloading attrs-25.4.0-py3-none-any.whl (67 kB)
# Downloading niquests-3.17.0-py3-none-any.whl (183 kB)
# Downloading urllib3_future-2.15.901-py3-none-any.whl (684 kB)
#    ---------------------------------------- 0.0/684.7 kB ? eta -:--:--
#    ---------------------------------------- 0.0/684.7 kB ? eta -:--:--
#    ---------------------------------------- 0.0/684.7 kB ? eta -:--:--
#    ---------------------------------------- 0.0/684.7 kB ? eta -:--:--
#    ---------------------------------------- 0.0/684.7 kB ? eta -:--:--
#    ---------------------------------------- 0.0/684.7 kB ? eta -:--:--
#    ---------------------------------------- 0.0/684.7 kB ? eta -:--:--
#    ---------------------------------------- 0.0/684.7 kB ? eta -:--:--
#    ---------------------------------------- 0.0/684.7 kB ? eta -:--:--
#    ---------------------------------------- 0.0/684.7 kB ? eta -:--:--
#    ---------------------------------------- 0.0/684.7 kB ? eta -:--:--
#    ---------------------------------------- 0.0/684.7 kB ? eta -:--:--
#    ---------------------------------------- 0.0/684.7 kB ? eta -:--:--
#    ---------------------------------------- 0.0/684.7 kB ? eta -:--:--
#    ---------------------------------------- 0.0/684.7 kB ? eta -:--:--
#    ---------------------------------------- 0.0/684.7 kB ? eta -:--:--
#    ---------------------------------------- 0.0/684.7 kB ? eta -:--:--
#    ---------------------------------------- 0.0/684.7 kB ? eta -:--:--
#    ---------------------------------------- 0.0/684.7 kB ? eta -:--:--
#    ---------------------------------------- 0.0/684.7 kB ? eta -:--:--
#    ---------------------------------------- 0.0/684.7 kB ? eta -:--:--
#    ---------------------------------------- 0.0/684.7 kB ? eta -:--:--
#    ---------------------------------------- 0.0/684.7 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/684.7 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/684.7 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/684.7 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/684.7 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/684.7 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/684.7 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/684.7 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/684.7 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/684.7 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/684.7 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/684.7 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/684.7 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/684.7 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/684.7 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/684.7 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/684.7 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/684.7 kB ? eta -:--:--
#    ----------------------------- --------- 524.3/684.7 kB 70.5 kB/s eta 0:00:03
#    ----------------------------- --------- 524.3/684.7 kB 70.5 kB/s eta 0:00:03
#    ----------------------------- --------- 524.3/684.7 kB 70.5 kB/s eta 0:00:03
#    ----------------------------- --------- 524.3/684.7 kB 70.5 kB/s eta 0:00:03
#    ----------------------------- --------- 524.3/684.7 kB 70.5 kB/s eta 0:00:03
#    --------------------------------------- 684.7/684.7 kB 85.7 kB/s eta 0:00:00
# Downloading jh2-5.0.10-cp37-abi3-win_amd64.whl (246 kB)
# Downloading qh3-1.5.6-cp37-abi3-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/2.0 MB 48.1 kB/s eta 0:00:31
#    ---------- ----------------------------- 0.5/2.0 MB 48.1 kB/s eta 0:00:31
#    ---------- ----------------------------- 0.5/2.0 MB 48.1 kB/s eta 0:00:31
#    ---------- ----------------------------- 0.5/2.0 MB 48.1 kB/s eta 0:00:31
#    ---------- ----------------------------- 0.5/2.0 MB 48.1 kB/s eta 0:00:31
#    ---------- ----------------------------- 0.5/2.0 MB 48.1 kB/s eta 0:00:31
#    ---------- ----------------------------- 0.5/2.0 MB 48.1 kB/s eta 0:00:31
#    ---------- ----------------------------- 0.5/2.0 MB 48.1 kB/s eta 0:00:31
#    ---------- ----------------------------- 0.5/2.0 MB 48.1 kB/s eta 0:00:31
#    ---------- ----------------------------- 0.5/2.0 MB 48.1 kB/s eta 0:00:31
#    ---------- ----------------------------- 0.5/2.0 MB 48.1 kB/s eta 0:00:31
#    ---------- ----------------------------- 0.5/2.0 MB 48.1 kB/s eta 0:00:31
#    ---------- ----------------------------- 0.5/2.0 MB 48.1 kB/s eta 0:00:31
#    ---------- ----------------------------- 0.5/2.0 MB 48.1 kB/s eta 0:00:31
#    --------------- ------------------------ 0.8/2.0 MB 61.1 kB/s eta 0:00:20
#    --------------- ------------------------ 0.8/2.0 MB 61.1 kB/s eta 0:00:20
#    --------------- ------------------------ 0.8/2.0 MB 61.1 kB/s eta 0:00:20
#    --------------- ------------------------ 0.8/2.0 MB 61.1 kB/s eta 0:00:20
#    --------------- ------------------------ 0.8/2.0 MB 61.1 kB/s eta 0:00:20
#    --------------- ------------------------ 0.8/2.0 MB 61.1 kB/s eta 0:00:20
#    --------------- ------------------------ 0.8/2.0 MB 61.1 kB/s eta 0:00:20
#    --------------- ------------------------ 0.8/2.0 MB 61.1 kB/s eta 0:00:20
#    --------------- ------------------------ 0.8/2.0 MB 61.1 kB/s eta 0:00:20
#    --------------- ------------------------ 0.8/2.0 MB 61.1 kB/s eta 0:00:20
#    --------------- ------------------------ 0.8/2.0 MB 61.1 kB/s eta 0:00:20
#    --------------------- ------------------ 1.0/2.0 MB 71.7 kB/s eta 0:00:14
#    --------------------- ------------------ 1.0/2.0 MB 71.7 kB/s eta 0:00:14
#    --------------------- ------------------ 1.0/2.0 MB 71.7 kB/s eta 0:00:14
#    --------------------- ------------------ 1.0/2.0 MB 71.7 kB/s eta 0:00:14
#    --------------------- ------------------ 1.0/2.0 MB 71.7 kB/s eta 0:00:14
#    --------------------- ------------------ 1.0/2.0 MB 71.7 kB/s eta 0:00:14
#    --------------------- ------------------ 1.0/2.0 MB 71.7 kB/s eta 0:00:14
#    --------------------- ------------------ 1.0/2.0 MB 71.7 kB/s eta 0:00:14
#    --------------------- ------------------ 1.0/2.0 MB 71.7 kB/s eta 0:00:14
#    --------------------- ------------------ 1.0/2.0 MB 71.7 kB/s eta 0:00:14
#    -------------------------- ------------- 1.3/2.0 MB 79.7 kB/s eta 0:00:09
#    -------------------------- ------------- 1.3/2.0 MB 79.7 kB/s eta 0:00:09
#    -------------------------- ------------- 1.3/2.0 MB 79.7 kB/s eta 0:00:09
#    -------------------------- ------------- 1.3/2.0 MB 79.7 kB/s eta 0:00:09
#    -------------------------- ------------- 1.3/2.0 MB 79.7 kB/s eta 0:00:09
#    -------------------------- ------------- 1.3/2.0 MB 79.7 kB/s eta 0:00:09
#    -------------------------- ------------- 1.3/2.0 MB 79.7 kB/s eta 0:00:09
#    -------------------------- ------------- 1.3/2.0 MB 79.7 kB/s eta 0:00:09
#    -------------------------- ------------- 1.3/2.0 MB 79.7 kB/s eta 0:00:09
#    -------------------------- ------------- 1.3/2.0 MB 79.7 kB/s eta 0:00:09
#    -------------------------- ------------- 1.3/2.0 MB 79.7 kB/s eta 0:00:09
#    -------------------------- ------------- 1.3/2.0 MB 79.7 kB/s eta 0:00:09
#    ------------------------------- -------- 1.6/2.0 MB 82.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.6/2.0 MB 82.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.6/2.0 MB 82.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.6/2.0 MB 82.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.6/2.0 MB 82.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.6/2.0 MB 82.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.6/2.0 MB 82.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.6/2.0 MB 82.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.6/2.0 MB 82.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.6/2.0 MB 82.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.6/2.0 MB 82.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.6/2.0 MB 82.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.6/2.0 MB 82.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.6/2.0 MB 82.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.6/2.0 MB 82.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.6/2.0 MB 82.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.6/2.0 MB 82.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.6/2.0 MB 82.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.6/2.0 MB 82.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.6/2.0 MB 82.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.6/2.0 MB 82.4 kB/s eta 0:00:06
#    ------------------------------------ --- 1.8/2.0 MB 77.1 kB/s eta 0:00:03
#    ------------------------------------ --- 1.8/2.0 MB 77.1 kB/s eta 0:00:03
#    ------------------------------------ --- 1.8/2.0 MB 77.1 kB/s eta 0:00:03
#    ------------------------------------ --- 1.8/2.0 MB 77.1 kB/s eta 0:00:03
#    ------------------------------------ --- 1.8/2.0 MB 77.1 kB/s eta 0:00:03
#    ------------------------------------ --- 1.8/2.0 MB 77.1 kB/s eta 0:00:03
#    ------------------------------------ --- 1.8/2.0 MB 77.1 kB/s eta 0:00:03
#    ------------------------------------ --- 1.8/2.0 MB 77.1 kB/s eta 0:00:03
#    ------------------------------------ --- 1.8/2.0 MB 77.1 kB/s eta 0:00:03
#    ------------------------------------ --- 1.8/2.0 MB 77.1 kB/s eta 0:00:03
#    ------------------------------------ --- 1.8/2.0 MB 77.1 kB/s eta 0:00:03
#    ------------------------------------ --- 1.8/2.0 MB 77.1 kB/s eta 0:00:03
#    ------------------------------------ --- 1.8/2.0 MB 77.1 kB/s eta 0:00:03
#    ------------------------------------ --- 1.8/2.0 MB 77.1 kB/s eta 0:00:03
#    ------------------------------------ --- 1.8/2.0 MB 77.1 kB/s eta 0:00:03
#    ---------------------------------------- 2.0/2.0 MB 72.9 kB/s eta 0:00:00
# Downloading wassima-2.0.4-py3-none-any.whl (144 kB)
# Downloading openmeteo_sdk-1.25.0-py3-none-any.whl (19 kB)
# Downloading flatbuffers-25.9.23-py2.py3-none-any.whl (30 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading url_normalize-2.2.1-py3-none-any.whl (14 kB)
# Installing collected packages: flatbuffers, wassima, url-normalize, typing-extensions, qh3, openmeteo-sdk, jh2, attrs, urllib3-future, retry-requests, cattrs, requests-cache, niquests, openmeteo-requests
#
#    ----------------------------------------  0/14 [flatbuffers]
#    ----- ----------------------------------  2/14 [url-normalize]
#   Attempting uninstall: typing-extensions
#    ----- ----------------------------------  2/14 [url-normalize]
#     Found existing installation: typing_extensions 4.12.2
#    ----- ----------------------------------  2/14 [url-normalize]
#    -------- -------------------------------  3/14 [typing-extensions]
#     Uninstalling typing_extensions-4.12.2:
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#       Successfully uninstalled typing_extensions-4.12.2
#    -------- -------------------------------  3/14 [typing-extensions]
#    -------- -------------------------------  3/14 [typing-extensions]
#    ----------- ----------------------------  4/14 [qh3]
#    ----------- ----------------------------  4/14 [qh3]
#    -------------- -------------------------  5/14 [openmeteo-sdk]
#    ----------------- ----------------------  6/14 [jh2]
#    ----------------- ----------------------  6/14 [jh2]
#    ----------------- ----------------------  6/14 [jh2]
#   Attempting uninstall: attrs
#    ----------------- ----------------------  6/14 [jh2]
#     Found existing installation: attrs 24.3.0
#    ----------------- ----------------------  6/14 [jh2]
#     Uninstalling attrs-24.3.0:
#    ----------------- ----------------------  6/14 [jh2]
#       Successfully uninstalled attrs-24.3.0
#    ----------------- ----------------------  6/14 [jh2]
#    -------------------- -------------------  7/14 [attrs]
#    -------------------- -------------------  7/14 [attrs]
#    ---------------------- -----------------  8/14 [urllib3-future]
#    ---------------------- -----------------  8/14 [urllib3-future]
#    ---------------------- -----------------  8/14 [urllib3-future]
#    ---------------------- -----------------  8/14 [urllib3-future]
#    ---------------------- -----------------  8/14 [urllib3-future]
#    ---------------------- -----------------  8/14 [urllib3-future]
#    ---------------------- -----------------  8/14 [urllib3-future]
#    ---------------------- -----------------  8/14 [urllib3-future]
#    ---------------------- -----------------  8/14 [urllib3-future]
#    ---------------------- -----------------  8/14 [urllib3-future]
#    ---------------------- -----------------  8/14 [urllib3-future]
#    ---------------------- -----------------  8/14 [urllib3-future]
#    ---------------------- -----------------  8/14 [urllib3-future]
#    ---------------------- -----------------  8/14 [urllib3-future]
#    ---------------------- -----------------  8/14 [urllib3-future]
#    ---------------------- -----------------  8/14 [urllib3-future]
#    ---------------------- -----------------  8/14 [urllib3-future]
#    ---------------------- -----------------  8/14 [urllib3-future]
#    ---------------------- -----------------  8/14 [urllib3-future]
#    ---------------------- -----------------  8/14 [urllib3-future]
#    ---------------------- -----------------  8/14 [urllib3-future]
#    ---------------------------- ----------- 10/14 [cattrs]
#    ---------------------------- ----------- 10/14 [cattrs]
#    ---------------------------- ----------- 10/14 [cattrs]
#    ---------------------------- ----------- 10/14 [cattrs]
#    ------------------------------- -------- 11/14 [requests-cache]
#    ------------------------------- -------- 11/14 [requests-cache]
#    ---------------------------------- ----- 12/14 [niquests]
#    ---------------------------------- ----- 12/14 [niquests]
#    ---------------------------------- ----- 12/14 [niquests]
#    ---------------------------------- ----- 12/14 [niquests]
#    ---------------------------------------- 14/14 [openmeteo-requests]
#
# Successfully installed attrs-25.4.0 cattrs-25.3.0 flatbuffers-25.9.23 jh2-5.0.10 niquests-3.17.0 openmeteo-requests-1.7.5 openmeteo-sdk-1.25.0 qh3-1.5.6 requests-cache-1.2.1 retry-requests-2.0.0 typing-extensions-4.15.0 url-normalize-2.2.1 urllib3-future-2.15.901 wassima-2.0.4
# Note: you may need to restart the kernel to use updated packages.

# %%
# =====================================================
# IMPORTS
# =====================================================
import pandas as pd
import requests_cache
import openmeteo_requests

from retry_requests import retry
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

import numpy as np
import time

# %%
# =====================================================
# CONSTANTS
# =====================================================
DATA_PATH = "C:\\Users\\ePadd\\OneDrive - University of Ghana\\Documents\\DATA SCIENCE\\DATA BLOOM\\ghana-maize-yield-prediction\\data\\raw\\maize_yield.csv"
RAW_WEATHER_PATH = "C:\\Users\\ePadd\\OneDrive - University of Ghana\\Documents\\DATA SCIENCE\\DATA BLOOM\\ghana-maize-yield-prediction\\data\\raw\\ghana_weather_raw.csv"
FINAL_OUTPUT_PATH = "C:\\Users\\ePadd\\OneDrive - University of Ghana\\Documents\\DATA SCIENCE\\DATA BLOOM\\ghana-maize-yield-prediction\\data\\processed\\maize_yield_with_weather.csv"

SEASON_MONTHS = [4, 5, 6, 7]  # Major season (Apr–Jul)
COUNTRY = "Ghana"


# =====================================================
# 1. LOAD & CLEAN DATA
# =====================================================
def clean_district_name(name: str) -> str:
    """Standardize district names for geocoding."""
    name = name.strip()

    if "(" in name:
        name = name.split("(")[0].strip()

    suffixes = ["Municipal", "Muni", "Metropolitan", "Metro", "District"]
    for suffix in suffixes:
        if name.lower().endswith(suffix.lower()):
            name = name[:-len(suffix)].strip()

    return name


def load_and_clean_data(path: str) -> pd.DataFrame:
    df = pd.read_csv(path)
    df["Cleaned_District"] = df["DISTRICT"].apply(clean_district_name)
    return df

# %%
# =====================================================
# 2. GEOCODING
# =====================================================
def geocode_districts(districts: list[str]) -> dict:
    geolocator = Nominatim(user_agent="ghana_maize_project_student")
    geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1.5)

    coords = {}

    for district in districts:
        try:
            location = geocode(f"{district}, {COUNTRY}")
            if location:
                coords[district] = {
                    "lat": location.latitude,
                    "lon": location.longitude
                }
            else:
                coords[district] = {"lat": None, "lon": None}

        except Exception:
            coords[district] = {"lat": None, "lon": None}

    return coords

# %%
# =====================================================
# 3. FETCH WEATHER DATA
# =====================================================
def setup_weather_client():
    cache_session = requests_cache.CachedSession(".cache", expire_after=-1)
    retry_session = retry(cache_session, retries=5, backoff_factor=0.2)
    return openmeteo_requests.Client(session=retry_session)


def fetch_weather_data(coords: dict, start_year: int, end_year: int) -> pd.DataFrame:
    client = setup_weather_client()
    weather_frames = []

    for district, c in coords.items():
        if c["lat"] is None:
            continue

        params = {
            "latitude": c["lat"],
            "longitude": c["lon"],
            "start_date": f"{start_year}-01-01",
            "end_date": f"{end_year}-12-31",
            "daily": [
                "temperature_2m_mean",
                "rain_sum",
                "shortwave_radiation_sum",
                "soil_moisture_0_to_7cm_mean"
            ],
            "timezone": "GMT"
        }

        try:
            response = client.weather_api(
                "https://archive-api.open-meteo.com/v1/archive",
                params=params
            )[0]

            daily = response.Daily()
            dates = pd.date_range(
                start=pd.to_datetime(daily.Time(), unit="s", utc=True),
                end=pd.to_datetime(daily.TimeEnd(), unit="s", utc=True),
                freq=pd.Timedelta(seconds=daily.Interval()),
                inclusive="left"
            )

            weather_frames.append(pd.DataFrame({
                "Date": dates,
                "Cleaned_District": district,
                "Temperature": daily.Variables(0).ValuesAsNumpy(),
                "Rainfall": daily.Variables(1).ValuesAsNumpy(),
                "Sunlight": daily.Variables(2).ValuesAsNumpy(),
                "Soil_Moisture": daily.Variables(3).ValuesAsNumpy()
            }))

        except Exception:
            continue

    return pd.concat(weather_frames, ignore_index=True) if weather_frames else pd.DataFrame()

# %%
# =====================================================
# 4. FEATURE ENGINEERING & MERGE
# =====================================================
def aggregate_seasonal_weather(weather_df: pd.DataFrame) -> pd.DataFrame:
    weather_df["Year"] = weather_df["Date"].dt.year
    weather_df["Month"] = weather_df["Date"].dt.month

    season_df = weather_df[weather_df["Month"].isin(SEASON_MONTHS)].copy()
    season_df["Water_Avail_Index"] = (
        season_df["Rainfall"] * season_df["Soil_Moisture"]
    )

    return (
        season_df
        .groupby(["Cleaned_District", "Year"])
        .agg({
            "Temperature": "mean",
            "Rainfall": "sum",
            "Sunlight": "sum",
            "Soil_Moisture": "mean",
            "Water_Avail_Index": "mean"
        })
        .reset_index()
    )

# %%
# =====================================================
# MAIN PIPELINE
# =====================================================
def main():
    df = load_and_clean_data(DATA_PATH)

    districts = df["Cleaned_District"].unique()
    coords = geocode_districts(districts)

    start_year, end_year = df["YEAR"].min(), df["YEAR"].max()
    weather_df = fetch_weather_data(coords, start_year, end_year)

    if weather_df.empty:
        print("No weather data retrieved.")
        return

    weather_df.to_csv(RAW_WEATHER_PATH, index=False)

    weather_summary = aggregate_seasonal_weather(weather_df)

    final_df = df.merge(
        weather_summary,
        left_on=["Cleaned_District", "YEAR"],
        right_on=["Cleaned_District", "Year"],
        how="left"
    )

    final_df.to_csv(FINAL_OUTPUT_PATH, index=False)
    print("Pipeline completed successfully.")


if __name__ == "__main__":
    main()
# Out:
# Pipeline completed successfully.

# %%
# ==========================================
# 1. ADVANCED CLEANING CONFIGURATION
# ==========================================

# MANUAL OVERRIDES: These are the ones that confuse the Geocoder.
# I have mapped your dataset's weird names to real Ghana cities.
manual_fixes = {
    "k. m. a.": "Kumasi",
    "a.m.a": "Accra",
    "s.t.m.a": "Sekondi-Takoradi",
    "sekondi-takoradi municipal (stma)": "Sekondi-Takoradi",
    "bolga": "Bolgatanga",
    "bolga municipal": "Bolgatanga",
    "bawku municipal": "Bawku",
    "kassena nankana muni.": "Navrongo", # Capital of Kassena Nankana
    "kassena nankana east": "Navrongo",
    "kassena nankana west": "Paga",
    "komenda-edina-eguafo-abirem": "Elmina", # Capital
    "suhum kraboa coaltar": "Suhum",
    "twifo-herman/l. denkyira": "Twifo Hemang",
    "fanteakwa": "Begoro", # Capital
    "asikuma-odoben-brakwa": "Breman Asikuma",
    "ajumako-enyan-esiam": "Ajumako",
    "ajumako-essiam-enyana": "Ajumako",
    "abura-asebu-kwamankese": "Abura Dunkwa",
    "ga east": "Abokobi",
    "ga west": "Amasaman",
    "ga south": "Weija",
    "ledzokuku-krowor": "Teshie",
    "dangme east": "Ada Foah",
    "dangme west": "Dodowa",
    "akuapim north": "Akropong",
    "akuapim south": "Aburi",
    "yilo krobo": "Somanya",
    "manya krobo": "Odumase Krobo",
    "savelugu/nanton": "Savelugu",
    "tolon/kumbungu": "Tolon",
    "zabzugu/tatale": "Zabzugu",
    "bunkpurugu/yunyoo": "Bunkpurugu",
    "sawla/tuna/kalba": "Sawla",
    "central gonja": "Buipe",
    "west gonja": "Damongo",
    "east gonja": "Salaga",
    "north tongu": "Battor Dugame",
    "south tongu": "Sogakope",
    "biakoye": "Nkonya",
    "jasikan": "Jasikan",
    "kadjebi": "Kadjebi",
    "krachi east": "Dambai",
    "krachi west": "Kete Krachi",
    "nkwanta": "Nkwanta",
    "bosumtwe-atwima-kwanwoma": "Kuntanase",
    "ahafo ano north": "Tepa",
    "ahafo ano south": "Mankranso",
    "atwima mponua": "Nyinahin",
    "atwima nwabiagya": "Nkawie",
    "ejusu juaben": "Ejisu",
    "offinso": "Offinso",
    "adansi north": "Fomena",
    "adansi south": "New Edubiase",
    "afigya sekyere": "Agona Ashanti",
    "sekyere east": "Effiduase",
    "sekyere west": "Mampong",
    "asante akim north": "Konongo",
    "asante akim south": "Juaso"
}

def robust_clean_district(name):
    # 0. Basic cleaning
    name = str(name).strip().lower()
    
    # 1. Check Manual Dictionary first (Fastest fix)
    if name in manual_fixes:
        return manual_fixes[name]
    
    # 2. Handle Slashes (Take the first town: "Tolon/Kumbungu" -> "Tolon")
    if '/' in name:
        name = name.split('/')[0].strip()
        
    # 3. Handle Parentheses (Remove them: "Bekwai (Amansie)" -> "Bekwai")
    if '(' in name:
        name = name.split('(')[0].strip()
        
    # 4. Remove Administrative Junk Words
    junk_words = ['municipal', 'muni', 'muni.', 'metropolitan', 'metro', 'district']
    for word in junk_words:
        if name.endswith(word):
            name = name.replace(word, '').strip()
            
    return name.title() # Return "Tolon" instead of "tolon"

# ==========================================
# 2. MAIN PROCESS
# ==========================================
print("Loading dataset...")
df = pd.read_csv(DATA_PATH)

print("Applying 'Super Cleaner' logic...")
df['Cleaned_District'] = df['DISTRICT'].apply(robust_clean_district)

unique_districts = df['Cleaned_District'].unique()
print(f"Cleaned down to {len(unique_districts)} unique locations.")

# ==========================================
# 3. GEOCODING WITH FALLBACK
# ==========================================
print("\nStarting Geocoding...")
geolocator = Nominatim(user_agent="ghana_maize_thesis_fixer")
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1.5)

district_coords = {}
failed_districts = []

for district in unique_districts:
    # Append ", Ghana" to help the geocoder context
    query = f"{district}, Ghana"
    
    try:
        location = geocode(query)
        if location:
            district_coords[district] = {'lat': location.latitude, 'lon': location.longitude}
            print(f"  ✓ Found: {district} ({location.latitude:.3f}, {location.longitude:.3f})")
        else:
            print(f"  ✗ FAILED: {district} (Will be skipped)")
            failed_districts.append(district)
            district_coords[district] = {'lat': None, 'lon': None}
            
    except Exception as e:
        print(f"  ! Error: {district} - {e}")
        district_coords[district] = {'lat': None, 'lon': None}

if failed_districts:
    print(f"\nWARNING: {len(failed_districts)} districts still failed geocoding:")
    print(failed_districts)
    print("You may need to add these to the 'manual_fixes' dictionary at the top of the script.")

# ==========================================
# 4. WEATHER FETCH (Same as before)
# ==========================================
print("\nFetching Weather Data (Open-Meteo)...")
# [This part is identical to the previous script, using district_coords]
# ... (Use the previous weather fetching code here)
# Out:
# Loading dataset...
# Applying 'Super Cleaner' logic...
# Cleaned down to 197 unique locations.
#
# Starting Geocoding...
#   ✓ Found: Bekwai (6.457, -1.584)
#   ✓ Found: Amansie Central (6.207, -1.828)
#   ✓ Found: Amansie West (6.440, -1.852)
#   ✓ Found: Ejura Sekyedumase (7.746, -0.987)
#   ✓ Found: Mampong (7.056, -1.404)
#   ✓ Found: Effiduase (6.851, -1.395)
#   ✓ Found: Agona Ashanti (6.934, -1.489)
#   ✓ Found: Tepa (7.005, -2.164)
#   ✓ Found: Mankranso (6.818, -1.863)
#   ✓ Found: Nyinahin (6.599, -2.117)
#   ✓ Found: Nkawie (6.668, -1.810)
#   ✓ Found: Ejisu (6.714, -1.467)
#   ✓ Found: Kuntanase (6.541, -1.477)
#   ✓ Found: Kwabre (6.790, -1.538)
#   ✓ Found: Offinso (6.931, -1.667)
#   ✓ Found: Fomena (6.281, -1.512)
#   ✓ Found: Obuasi (6.212, -1.689)
#   ✓ Found: Adansi  South (6.064, -1.396)
#   ✓ Found: Konongo (6.623, -1.215)
#   ✓ Found: Juaso (6.583, -1.119)
#   ✓ Found: Kumasi (6.699, -1.623)
#   ✓ Found: Bosome Freho (6.368, -1.366)
#   ✓ Found: Sekyere Central (6.991, -1.367)
#   ✓ Found: Sekyere Afram Plains (7.074, -1.126)
#   ✓ Found: Sekyere South (6.934, -1.489)
#   ✓ Found: Afigya Kwabre (6.814, -1.653)
#   ✗ FAILED: Bosumtwe (Will be skipped)
#   ✓ Found: Atwima Kwanwoma (6.754, -1.644)
#   ✓ Found: Kwabre East (6.790, -1.538)
#   ✓ Found: Offinso North (7.399, -1.956)
#   ✓ Found: Sunyani (7.338, -2.331)
#   ✓ Found: Asutifi (7.077, -2.525)
#   ✓ Found: Wenchi (7.738, -2.104)
#   ✓ Found: Dormaa (7.239, -2.857)
#   ✓ Found: Berekum (7.450, -2.582)
#   ✓ Found: Tano North (7.193, -2.208)
#   ✓ Found: Tano South (7.161, -1.997)
#   ✓ Found: Sene (7.666, -0.182)
#   ✓ Found: Nkoranza (7.562, -1.704)
#   ✓ Found: Techiman (7.585, -1.936)
#   ✓ Found: Asunafo North (6.815, -2.677)
#   ✓ Found: Asunafo South (6.563, -2.533)
#   ✓ Found: Jaman North (7.913, -2.697)
#   ✓ Found: Jaman South (7.620, -2.796)
#   ✓ Found: Kintampo North (8.049, -1.731)
#   ✓ Found: Kintampo South (7.943, -1.734)
#   ✓ Found: Atebubu -Amantin (7.746, -0.987)
#   ✓ Found: Pru (7.964, -0.955)
#   ✓ Found: Tain (7.961, -2.142)
#   ✓ Found: Sunyani West (7.403, -2.463)
#   ✓ Found: Dormaa East (7.264, -2.641)
#   ✓ Found: Nkoranza South (7.562, -1.710)
#   ✓ Found: Nkoranza North (7.718, -1.644)
#   ✓ Found: Upper Denkyira (5.961, -1.932)
#   ✓ Found: Twifo Hemang (5.487, -1.532)
#   ✓ Found: Assin South (5.529, -1.271)
#   ✓ Found: Assin North (5.825, -1.374)
#   ✓ Found: Abura Dunkwa (5.340, -1.171)
#   ✓ Found: Breman Asikuma (5.582, -0.999)
#   ✓ Found: Mfantsiman (5.276, -1.035)
#   ✓ Found: Elmina (5.086, -1.351)
#   ✓ Found: Ajumako (5.428, -0.959)
#   ✗ FAILED: Awutu-Efutu-Senya (Will be skipped)
#   ✓ Found: Gomoa (5.322, -0.801)
#   ✓ Found: Cape Coast (5.107, -1.243)
#   ✓ Found: Agona (6.933, -1.490)
#   ✓ Found: Upper Denkyira East (5.961, -1.778)
#   ✓ Found: Upper Denkyira West (6.108, -2.069)
#   ✓ Found: Effutu (5.383, -0.597)
#   ✓ Found: Awutu-Senya (5.404, -0.518)
#   ✓ Found: Gomoa West (5.284, -0.737)
#   ✓ Found: Gomoa East (5.528, -0.424)
#   ✓ Found: Agona West (4.890, -1.961)
#   ✓ Found: Agona East (5.644, -0.752)
#   ✓ Found: Birim South (5.901, -1.030)
#   ✓ Found: West Akim (5.861, -0.666)
#   ✓ Found: Suhum (6.036, -0.455)
#   ✓ Found: Aburi (5.847, -0.175)
#   ✓ Found: Akropong (6.742, -1.731)
#   ✓ Found: New Juaben (6.089, -0.260)
#   ✓ Found: Somanya (6.105, -0.015)
#   ✗ FAILED: East Akim (Will be skipped)
#   ✓ Found: Atiwa (6.395, -0.597)
#   ✓ Found: Kwaebibirem (6.234, -0.876)
#   ✓ Found: Birim North (6.347, -0.997)
#   ✓ Found: Kwahu West (6.553, -0.769)
#   ✓ Found: Begoro (6.385, -0.376)
#   ✓ Found: Afram Plains (7.044, -0.080)
#   ✓ Found: Asuogyaman (6.363, 0.095)
#   ✓ Found: Odumase Krobo (6.152, 0.019)
#   ✓ Found: Birim Central (5.915, -0.987)
#   ✓ Found: Akyemansa (6.082, -1.115)
#   ✓ Found: Kwahu South (6.603, -0.777)
#   ✓ Found: Kwahu East (6.672, -0.749)
#   ✓ Found: Lower Manya Krobo (6.213, -0.040)
#   ✓ Found: Upper Manya Krobo (6.395, -0.142)
#   ✓ Found: Tema (5.660, -0.010)
#   ✓ Found: Abokobi (5.733, -0.206)
#   ✓ Found: Amasaman (5.703, -0.299)
#   ✗ FAILED: Dangbe West (Will be skipped)
#   ✓ Found: Ada Foah (5.782, 0.633)
#   ✓ Found: Accra (5.557, -0.201)
#   ✓ Found: Ashaiman (5.694, -0.030)
#   ✓ Found: Weija (5.579, -0.331)
#   ✓ Found: Teshie (5.582, -0.114)
#   ✓ Found: Adenta-Madina (5.689, -0.167)
#   ✓ Found: Adentan (5.704, -0.169)
#   ✓ Found: Dodowa (5.880, -0.105)
#   ✓ Found: Buipe (8.789, -1.468)
#   ✓ Found: Damongo (9.085, -1.820)
#   ✓ Found: Yendi (9.447, -0.004)
#   ✓ Found: Nanumba North (8.922, -0.139)
#   ✓ Found: Nanumba South (8.766, 0.055)
#   ✓ Found: Karaga (9.927, -0.432)
#   ✓ Found: Gushiegu (9.931, -0.144)
#   ✓ Found: Bunkpurugu (10.519, 0.096)
#   ✓ Found: East Mamprusi (10.532, -0.441)
#   ✓ Found: Savelugu (9.626, -0.826)
#   ✓ Found: Salaga (8.551, -0.520)
#   ✓ Found: Tamale (9.405, -0.842)
#   ✓ Found: Sawla (9.273, -2.414)
#   ✓ Found: Bole (9.032, -2.490)
#   ✓ Found: Saboba (9.705, 0.317)
#   ✓ Found: Tolon (9.432, -1.067)
#   ✓ Found: West Mamprusi (10.297, -0.764)
#   ✓ Found: Zabzugu (9.294, 0.367)
#   ✓ Found: Kpandai (8.464, -0.012)
#   ✓ Found: Chereponi (10.137, 0.291)
#   ✓ Found: Builsa (10.710, -1.259)
#   ✗ FAILED: Kasina-Nankana (Will be skipped)
#   ✗ FAILED: Talensi Nabdam (Will be skipped)
#   ✓ Found: Bolgatanga (10.785, -0.849)
#   ✓ Found: Garu Tempane (10.856, -0.154)
#   ✓ Found: Bawku (11.061, -0.242)
#   ✓ Found: Bawku West (10.939, -0.481)
#   ✓ Found: Bongo (10.909, -0.808)
#   ✓ Found: Navrongo (10.893, -1.088)
#   ✓ Found: Paga (10.970, -1.102)
#   ✓ Found: Builsa North (10.733, -1.286)
#   ✓ Found: Builsa South (10.530, -1.262)
#   ✓ Found: Binduri (10.969, -0.306)
#   ✓ Found: Pusiga (11.085, -0.128)
#   ✓ Found: Wa West (9.899, -2.683)
#   ✓ Found: Wa East (10.297, -1.968)
#   ✓ Found: Wa (10.062, -2.505)
#   ✓ Found: Lawra (10.643, -2.893)
#   ✓ Found: Sissala East (10.597, -1.851)
#   ✓ Found: Sissala West (10.990, -2.599)
#   ✗ FAILED: Jirapa-Lambussie (Will be skipped)
#   ✓ Found: Nadowli (10.372, -2.664)
#   ✓ Found: Jirapa (10.537, -2.701)
#   ✓ Found: Lambussie-Karni (10.997, -2.748)
#   ✓ Found: Dafiama-Bussie-Issa (10.467, -2.536)
#   ✓ Found: Nandom (10.852, -2.760)
#   ✗ FAILED: Battor Dugame (Will be skipped)
#   ✓ Found: Sogakope (5.999, 0.595)
#   ✓ Found: Akatsi (6.131, 0.798)
#   ✓ Found: Keta (5.922, 0.991)
#   ✓ Found: Ketu (6.077, 1.071)
#   ✓ Found: North Dayi (6.888, 0.278)
#   ✓ Found: South Dayi (6.686, 0.333)
#   ✓ Found: Hohoe (7.153, 0.478)
#   ✓ Found: Jasikan (7.411, 0.471)
#   ✓ Found: Kadjebi (7.526, 0.476)
#   ✓ Found: Nkwanta (8.263, 0.521)
#   ✓ Found: Kete Krachi (7.798, -0.049)
#   ✓ Found: Dambai (8.068, 0.179)
#   ✓ Found: Ho (6.613, 0.469)
#   ✓ Found: Adaklu Anyigbe (6.451, 0.625)
#   ✓ Found: Ketu North (6.233, 0.998)
#   ✓ Found: Ketu South (6.077, 1.071)
#   ✓ Found: Kpando (6.997, 0.294)
#   ✓ Found: Nkonya (6.283, -2.624)
#   ✓ Found: Nkwanta North (8.552, 0.235)
#   ✓ Found: Nkwanta South (8.250, 0.413)
#   ✗ FAILED: Shama Ahanta East (Will be skipped)
#   ✓ Found: West Ahanta (4.903, -1.911)
#   ✗ FAILED: Mporhor Wassa East (Will be skipped)
#   ✓ Found: Wassa West (5.806, -2.432)
#   ✓ Found: East Nzema (4.868, -2.239)
#   ✓ Found: Jomoro (5.760, -2.591)
#   ✓ Found: Amenfi East (5.778, -2.095)
#   ✓ Found: Amenfi  West (5.775, -2.476)
#   ✓ Found: Aowin -Suaman (5.828, -2.821)
#   ✓ Found: Bibiani-Anhwiaso-Bekwai (6.296, -2.234)
#   ✗ FAILED: Sefwi-Wiaso (Will be skipped)
#   ✓ Found: Bia (6.198, -3.001)
#   ✗ FAILED: Juabeso (Will be skipped)
#   ✓ Found: Sekondi-Takoradi (4.927, -1.749)
#   ✓ Found: Shama (5.010, -1.629)
#   ✓ Found: Ahanta West (4.851, -1.987)
#   ✓ Found: Tarkwa Nsuaem (5.301, -1.999)
#   ✓ Found: Prestea Huni-Valley (5.445, -2.041)
#   ✓ Found: Nzema East (5.086, -2.223)
#   ✗ FAILED: Ellembele (Will be skipped)
#   ✓ Found: Sefwi-Wiawso (6.205, -2.488)
#   ✓ Found: Akontombra (6.094, -2.655)
#
# WARNING: 13 districts still failed geocoding:
# ['Bosumtwe', 'Awutu-Efutu-Senya', 'East Akim', 'Dangbe West', 'Kasina-Nankana', 'Talensi Nabdam', 'Jirapa-Lambussie', 'Battor Dugame', 'Shama Ahanta East', 'Mporhor Wassa East', 'Sefwi-Wiaso', 'Juabeso', 'Ellembele']
# You may need to add these to the 'manual_fixes' dictionary at the top of the script.
#
# Fetching Weather Data (Open-Meteo)...
